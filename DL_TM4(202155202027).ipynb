# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhAdeRizki/202155202027-MuhammadAdeRizki/blob/master/DL_TM4(202155202027).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras import datasets,models,layers

# %%
data = tf.keras.datasets.cifar10
# The CIFAR10 dataset contains 60,000 color images in 10 classes,
# with 6,000 images in each class. The dataset is divided into 50,000 training
# images and 10,000 testing images.

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
test_images.shape
# Out:
# (10000, 32, 32, 3)

# %%
print(train_labels[0])
# Out:
# [6]

# %%
print(train_images[1])
# Out:
# [[[154 177 187]
#   [126 137 136]
#   [105 104  95]
#   ...
#   [ 91  95  71]
#   [ 87  90  71]
#   [ 79  81  70]]
#
#  [[140 160 169]
#   [145 153 154]
#   [125 125 118]
#   ...
#   [ 96  99  78]
#   [ 77  80  62]
#   [ 71  73  61]]
#
#  [[140 155 164]
#   [139 146 149]
#   [115 115 112]
#   ...
#   [ 79  82  64]
#   [ 68  70  55]
#   [ 67  69  55]]
#
#  ...
#
#  [[175 167 166]
#   [156 154 160]
#   [154 160 170]
#   ...
#   [ 42  34  36]
#   [ 61  53  57]
#   [ 93  83  91]]
#
#  [[165 154 128]
#   [156 152 130]
#   [159 161 142]
#   ...
#   [103  93  96]
#   [123 114 120]
#   [131 121 131]]
#
#  [[163 148 120]
#   [158 148 122]
#   [163 156 133]
#   ...
#   [143 133 139]
#   [143 134 142]
#   [143 133 144]]]

# %%
plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.grid(False)

plt.show()

# %%
for i in range(6):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(train_images[i])
plt.show()

# %%
#Normalize

train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
model = tf.keras.models.Sequential([
                        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                        tf.keras.layers.Flatten(),
                        tf.keras.layers.Dense(128, activation='relu'),
                        tf.keras.layers.Dense(10, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 188810 (737.54 KB)
# Trainable params: 188810 (737.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=50,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 70s 44ms/step - loss: 1.5061 - accuracy: 0.4509 - val_loss: 1.2709 - val_accuracy: 0.5430
# Epoch 2/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.1859 - accuracy: 0.5797 - val_loss: 1.1650 - val_accuracy: 0.5836
# Epoch 3/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.0499 - accuracy: 0.6288 - val_loss: 1.0045 - val_accuracy: 0.6469
# Epoch 4/50
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.9476 - accuracy: 0.6652 - val_loss: 0.9906 - val_accuracy: 0.6532
# Epoch 5/50
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.8753 - accuracy: 0.6916 - val_loss: 0.9304 - val_accuracy: 0.6758
# Epoch 6/50
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0
50
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.2055 - accuracy: 0.9255 - val_loss: 1.7653 - val_accuracy: 0.6714
# Epoch 30/50
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.1911 - accuracy: 0.9315 - val_loss: 1.7948 - val_accuracy: 0.6762
# Epoch 31/50
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.1895 - accuracy: 0.9325 - val_loss: 1.8232 - val_accuracy: 0.6719
# Epoch 32/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1828 - accuracy: 0.9348 - val_loss: 1.9235 - val_accuracy: 0.6735
# Epoch 33/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1756 - accuracy: 0.9364 - val_loss: 1.9403 - val_accuracy: 0.6816
# Epoch 34/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1681 - accuracy: 0.9396 - val_loss: 1.9159 - val_accuracy: 0.6845
# Epoch 35/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1623 - accuracy: 0.9415 - val_loss: 2.2367 - val_accuracy: 0.6696
# Epoch 36/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1612 - accuracy: 0.9423 - val_loss: 2.0989 - val_accuracy: 0.6817
# Epoch 37/50
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.1549 - accuracy: 0.9451 - val_loss: 2.0962 - val_accuracy: 0.6838
# Epoch 38/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1583 - accuracy: 0.9436 - val_loss: 2.1226 - val_accuracy: 0.6772
# Epoch 39/50
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.1434 - accuracy: 0.9494 - val_loss: 2.3438 - val_accuracy: 0.6696
# Epoch 40/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1389 - accuracy: 0.9509 - val_loss: 2.3665 - val_accuracy: 0.6796
# Epoch 41/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1445 - accuracy: 0.9503 - val_loss: 2.3880 - val_accuracy: 0.6754
# Epoch 42/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1497 - accuracy: 0.9478 - val_loss: 2.4715 - val_accuracy: 0.6711
# Epoch 43/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1313 - accuracy: 0.9543 - val_loss: 2.4892 - val_accuracy: 0.6693
# Epoch 44/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1465 - accuracy: 0.9495 - val_loss: 2.4768 - val_accuracy: 0.6667
# Epoch 45/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1233 - accuracy: 0.9565 - val_loss: 2.5006 - val_accuracy: 0.6748
# Epoch 46/50
# 1563/1563 [==============================] - 74s 48ms/step - loss: 0.1240 - accuracy: 0.9577 - val_loss: 2.6284 - val_accuracy: 0.6680
# Epoch 47/50
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.1336 - accuracy: 0.9542 - val_loss: 2.6650 - val_accuracy: 0.6718
# Epoch 48/50
# 1563/1563 [==============================] - 70s 44ms/step - loss: 0.1222 - accuracy: 0.9575 - val_loss: 2.6855 - val_accuracy: 0.6671
# Epoch 49/50
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.1239 - accuracy: 0.9573 - val_loss: 2.6945 - val_accuracy: 0.6781
# Epoch 50/50
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.1245 - accuracy: 0.9584 - val_loss: 2.7004 - val_accuracy: 0.6722

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
